# %%
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('/Users/weimingchin/Desktop/term 7/Spatial Design/spatialworld/image-segmentation/example.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
original_h = image.shape[0]
original_w = image.shape[1]
print(original_w, original_h)
plt.figure(figsize=(10, 10))
plt.imshow(image)
# Out:
# 1024 1024

# %%
# !python3 Inference.py  --model_path FastSAM.pt --img_path /Users/weimingchin/Desktop/term 7/Spatial Design/spatialworld/image-segmentation/example.jpg --imgsz 1024
# Out:
# Traceback (most recent call last):
#   File "/Users/weimingchin/Desktop/term 7/Spatial Design/spatialworld/image-segmentation/fast_sam/Inference.py", line 2, in <module>
#     from fastsam import FastSAM, FastSAMPrompt
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'fastsam'
